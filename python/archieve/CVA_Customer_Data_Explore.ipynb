# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline



import numpy as np
# import pandas as pd
# import pandas_profiling as pp
import seaborn as sns
# import matplotlib.pyplot as plt
# import statsmodels.api as sm
# import math 
# import pylab
from scipy import stats
# from scipy.stats import kurtosis, skew
# from statsmodels.stats import diagnostic as diag
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LinearRegression
# from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# # pd.options.display.max_rows = 10
# pd.options.display.max_columns = 10
# pd.set_option('display.precision', 4)

# %%
df = pd.read_csv("../data/CVA_Customer_Data.csv", index_col='OriginalCustomerNumber')
# df=pd.read_excel("../data/CVA_Data.xlsx")
df.shape
# Out:
# (9837, 66)

# %%
corr = round(df.corrwith(df._Total_Number_Of_OpenContracts),2)
corr.to_csv('..\\data\\Output\\corr.csv',header = True)

# %%
test = df[['_Total_Number_Of_OpenContracts','_SUM_PM_Opportunity']]

sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_SUM_PM_Opportunity']]

#note: from now on if the chart looks like with outlikers, i will drop over 3 abs standard deviations
# filtered_data = test.drop(test.index[test.Expenditure_12M_PartsNServices >= 500000])
# test = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]

sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','OLGAAmount']]
test = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
test = test.drop(test.index[test._Total_Number_Of_OpenContracts > 50])
test = test.drop(test.index[test.OLGAAmount > 1250000])
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','CATFleetSize']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Total_Number_Of_ClosedContracts']] #note customer level vs equipment level
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Previously_Had_Contract']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','PartsDCAL']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
# Out:
# C:\Users\julianyang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
test = df[['_Total_Number_Of_OpenContracts','ServiceDCAL']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
# Out:
# C:\Users\julianyang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
test = df[['_Total_Number_Of_OpenContracts','HasConnectedDevices']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Possibly_D4M']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
# Out:
# C:\Users\julianyang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
test = df[['_Total_Number_Of_OpenContracts','_Prefer_To_Rent']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
# Out:
# C:\Users\julianyang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
test = df[['_Total_Number_Of_OpenContracts','_Percentage_Parts_Purchased_Thru_Service_Last_6_Months']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
# Out:
# C:\Users\julianyang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
test = df[['_Total_Number_Of_OpenContracts','_Percentage_Parts_Purchased_Online_Last_6_Months']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Percentage_Parts_Purchased_Direct_Last_6_Months']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_SUM_PM_Opportunity']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','ManufactureYear']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Months_Until_Warranty_Ends']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(filtered_data, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','_Prefer_To_Rent']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})

# %%
test = df[['_Total_Number_Of_OpenContracts','CATFleetSize']]
filtered_data = test[(np.abs(stats.zscore(test)) < 3).any(axis=1)]
sns.pairplot(test, kind='reg', diag_kind='hist',height=4, aspect=1,plot_kws={'scatter_kws': {'alpha': 0.7}})
