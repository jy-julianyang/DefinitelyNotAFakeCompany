# %%
import numpy as np
import pandas as pd
import pyodbc

# %%
driver = 'ODBC Driver 17 for SQL Server'
server = 'sqlcat1.toromont.com,1685' 
                      
conn = pyodbc.connect('Driver={};Server={};Trusted_Connection=yes; \
                      ApplicationIntent=ReadOnly;database=Appdb_Equiplink'
                      .format(driver, server))

# %%
sql = """
---Jeremy Equipment List---
WITH JWL as (
SELECT [EquipmentId] as ID
,SerialNumber AS SN
,EMT
  FROM [AppDb_Equiplink].[AI].[ConditionSummary]
  WHERE
  CMA = 'Jeremy Froats'
  AND
  [EMT] = 1
)
---Event List under 360 days---
SELECT
         jwl.SN
         ,CASE
         WHEN Type = 1 Then 'SOS'
         WHEN Type = 8 Then 'EventCode'
         WHEN Type = 16 Then 'DiagnosticCode'
         else ''
         End as Type
      ,CONVERT(varchar, EventDate, 1) as Date
	  --,EventDate
      ,[Identifier] as Message
      ,[Description]
      ,[Details]
      ,[SMU]
      ,CASE
         WHEN EH.[Level] = 8 THEN 'LV3'
         WHEN EH.[Level] = 4 THEN 'LV2'
         WHEN EH.[Level] = 2 THEN 'LV1'
         ELSE ''
         END AS Severity
  FROM [AppDb_Equiplink].[AI].[EventHistory] as EH
inner join JWL
       ON EH.EquipmentId = JWL.ID
  WHERE EventDate > DATEADD(day,-5,CURRENT_TIMESTAMP) 
and 
  Type in (1,8,16,256,8192,4294967296)

  order by SN,Type,description,EventDate desc
---Points for the Events:Compare to Health Reference Table---
"""

# %%
df = pd.read_sql(sql, conn)
df.head()
# Out:
#          SN            Type      Date  \
# 0  2T400506  DiagnosticCode  04/09/20
# 1  2T400506       EventCode  04/13/20
# 2  2T400583                  04/13/20
# 3  2T400583       EventCode  04/13/20
# 4  2T400583       EventCode  04/13/20
#
#                                              Message  \
# 0                MID: -1, CID: 5519, FMI: 18, OCC: 5
# 1                          MID: 389,EID: 1449,OCC: 1
# 2                                         v3.3619423
# 3        ET/PSR Active MID: 27,EID: 764, Severity: 1
# 4  ET/PSR Logged MID: 27,EID: 1668,FMI: ,OCC: 5, ...
#
#                                          Description  \
# 0                                CID: 5519 / MID: -1
# 1                      Transmission/Chassis Control
# 2  Dealer Process/Heavy Rents Off Rent Full V4.6 ...
# 3                               Transmission/Chassis
# 4                               Transmission/Chassis
#
#                                          Details     SMU Severity
# 0                    Low - moderate severity (2)     NaN      LV2
# 1  Low Brake Accumulator Precharge Gas Pressure      NaN      LV3
# 2                                                 1984.0      LV3
# 3                     Trip Data Memory Full (ET)  1985.0      LV1
# 4          High Center Axle Oil Temperature (ET)  1167.0      LV1

# %% [markdown]
# # Split

# %%
eventcodedf = df[(df.Type=='EventCode') | (df.Type=='DiagnosticCode')]
split = eventcodedf.loc[:, 'Message'].str.split(pat=',', expand=True)

test = (pd.melt(split.reset_index(), id_vars='index').dropna().
 drop(columns='variable').set_index('index')
 .value.str.split(':', expand=True)
 .reset_index()
 .pivot(index='index', columns=0, values=1)
#  .head()
)
#combine columns
test['OCC'] = test['OCC'].fillna(test[' OCC'])
test['FMI'] = test['FMI'].fillna(test[' FMI'])
test['CID'] = test['CID'].fillna(test[' CID'])
test['MID'] = test['MID'].fillna(test['ET/PSR Logged MID']).fillna(test['ET/PSR Active MID'])
#replace ' Severity' with ''
test['OCC'] = test['OCC'].str.replace('Severity$', '', regex=True)
# ' Severity' check
# test[test['OCC'].str.contains('Severity')]
#drop columns
test = test.drop(columns=[' OCC', ' FMI', ' CID', 'ET/PSR Logged MID', 'ET/PSR Active MID'])
#rename ' Severity' to 'SeverityFrmMsg'
test = test.rename(columns={' Severity': 'SeverityFrmMsg'})

# %%
# test[test['SeverityFrmMsg'].notnull()]
test.head()
# Out:
# 0     SeverityFrmMsg    CID    EID  FMI   MID  OCC
# index
# 0                NaN   5519    NaN   18    -1    5
# 1                NaN    NaN   1449  NaN   389    1
# 3                  1    NaN    764  NaN    27  NaN
# 4                  2    NaN   1668         27    5
# 5                  1    NaN     47         27    1

# %%
eventcat = pd.concat([eventcodedf, test], axis=1)
# eventcat.loc[[198],]
eventcat.head()
# Out:
#          SN            Type      Date  \
# 0  2T400506  DiagnosticCode  04/09/20
# 1  2T400506       EventCode  04/13/20
# 3  2T400583       EventCode  04/13/20
# 4  2T400583       EventCode  04/13/20
# 5  2T400583       EventCode  04/13/20
#
#                                              Message  \
# 0                MID: -1, CID: 5519, FMI: 18, OCC: 5
# 1                          MID: 389,EID: 1449,OCC: 1
# 3        ET/PSR Active MID: 27,EID: 764, Severity: 1
# 4  ET/PSR Logged MID: 27,EID: 1668,FMI: ,OCC: 5, ...
# 5  ET/PSR Logged MID: 27,EID: 47,FMI: ,OCC: 1, Se...
#
#                      Description  \
# 0            CID: 5519 / MID: -1
# 1  Transmission/Chassis Control
# 3           Transmission/Chassis
# 4           Transmission/Chassis
# 5           Transmission/Chassis
#
#                                          Details     SMU Severity  \
# 0                    Low - moderate severity (2)     NaN      LV2
# 1  Low Brake Accumulator Precharge Gas Pressure      NaN      LV3
# 3                     Trip Data Memory Full (ET)  1985.0      LV1
# 4          High Center Axle Oil Temperature (ET)  1167.0      LV1
# 5                Transmission Abuse Warning (ET)  1884.0      LV1
#
#   SeverityFrmMsg    CID    EID  FMI   MID  OCC
# 0            NaN   5519    NaN   18    -1    5
# 1            NaN    NaN   1449  NaN   389    1
# 3              1    NaN    764  NaN    27  NaN
# 4              2    NaN   1668         27    5
# 5              1    NaN     47         27    1

# %%
#write csv
eventcat.to_csv('event_test.csv', index=False)

# %% [markdown]
# # Draft

# %%
test[test[' CID'].notnull()]

# %%
(pd.melt(split.reset_index(), id_vars='index').dropna().
 drop(columns='variable').set_index('index')
 .value.str.split(':', expand=True)
 .reset_index()
 .pivot(index='index', columns=0, values=1)
 .head()
)

# %%
(pd.melt(split.reset_index(), id_vars='index').dropna()
 .drop(columns='variable').set_index('index')
 .value.str.split(':', expand=True)
 # add strip empty space step
 .reset_index()
 .pivot(index='index', columns=0, values=1)
)

# %%
eventcodedf = df[(df.Type=='EventCode') | (df.Type=='DiagnosticCode')]
split = eventcodedf.loc[:, 'Message'].str.split(pat=',', expand=True)
eventcat = pd.concat([eventcodedf, split], axis=1)
eventcat.head()
pd.options.display.max_colwidth = 1000
eventcat
# eventcat.loc[[126],]
# Out:
#                      SN            Type      Date  \
# 1              2T300763       EventCode  04/08/20
# 2              2T300763       EventCode  04/08/20
# 3              2T400506  DiagnosticCode  04/09/20
# 4              2T400506       EventCode  04/13/20
# 5              2T400517       EventCode  04/08/20
# 6              2T400517       EventCode  04/08/20
# 7              3T300392       EventCode  04/08/20
# 8              3T300405       EventCode  04/08/20
# 9              3T300405       EventCode  04/08/20
# 10             3T300405       EventCode  04/08/20
# 11             3T301112       EventCode  04/13/20
# 12             3T600663  DiagnosticCode  04/12/20
# 13             3T600663       EventCode  04/11/20
# 14             3T601280       EventCode  04/12/20
# 15             3T601280       EventCode  04/11/20
# 16             3T601280       EventCode  04/12/20
# 17             3T601280       EventCode  04/08/20
# 18   3T602123            DiagnosticCode  04/09/20
# 19   3T602123                 EventCode  04/12/20
# 20   3T602123                 EventCode  04/12/20
# 21   3T602123                 EventCode  04/09/20
# 22   3T602127            DiagnosticCode  04/09/20
# 23   3T602127                 EventCode  04/13/20
# 24   3T602127                 EventCode  04/13/20
# 25   3T602127                 EventCode  04/12/20
# 26   3T602127                 EventCode  04/10/20
# 27   3T602127                 EventCode  04/10/20
# 28   3T602127                 EventCode  04/09/20
# 29   3T602127                 EventCode  04/09/20
# 30   3T602127                 EventCode  04/09/20
# ..                  ...             ...       ...
# 192            REP00821  DiagnosticCode  04/09/20
# 193            REP00821  DiagnosticCode  04/08/20
# 194            RKB00877  DiagnosticCode  04/10/20
# 195            RKB00877  DiagnosticCode  04/09/20
# 196            RKB00877  DiagnosticCode  04/09/20
# 198            RKB21234       EventCode  04/13/20
# 199            SGG00952       EventCode  04/10/20
# 200            SGG00952       EventCode  04/08/20
# 201            SGJ20133  DiagnosticCode  04/09/20
# 202            SGJ20133  DiagnosticCode  04/08/20
# 204            SL800136  DiagnosticCode  04/08/20
# 205            SL800136  DiagnosticCode  04/09/20
# 206            SL800136  DiagnosticCode  04/09/20
# 207            SL800136  DiagnosticCode  04/09/20
# 208            SL800136  DiagnosticCode  04/08/20
# 209            SL800136  DiagnosticCode  04/08/20
# 217            TNJ00336       EventCode  04/13/20
# 218            TNJ00336       EventCode  04/09/20
# 219            TNJ00336       EventCode  04/08/20
# 220            TNJ00336       EventCode  04/08/20
# 221            TNJ00336       EventCode  04/08/20
# 222            TNJ00336       EventCode  04/08/20
# 223            TNJ00336       EventCode  04/08/20
# 224            TNJ00336       EventCode  04/08/20
# 225            XCF00613  DiagnosticCode  04/08/20
# 226            XCF00613       EventCode  04/09/20
# 227            XDJ01188  DiagnosticCode  04/08/20
# 228            XDJ01188       EventCode  04/08/20
# 229            XDJ01188       EventCode  04/08/20
# 230            XDJ01196       EventCode  04/09/20
#
#                                                         Message  \
# 1                                     MID: 389,EID: 47,OCC: 104
# 2                                     MID: 389,EID: 47,OCC: 103
# 3                           MID: -1, CID: 5519, FMI: 18, OCC: 5
# 228                                   MID: 341,EID: 1052,OCC: 1
# 229                                   MID: 272,EID: 1388,OCC: 1
# 230                                   MID: 272,EID: 1388,OCC: 4
#
#                                                                   Description  \
# 1                                               Transmission/Chassis Control
# 2                                               Transmission/Chassis Control
# 3                                                         CID: 5519 / MID: -1
# 4                                               Transmission/Chassis Control
# 5                                                     Chassis Control Module
# 6                                                     Chassis Control Module
# 7                                                     Chassis Control Module
# 8                                                     Chassis Control Module
# 9                                                               Transmission
# 10                                                              Transmission
# 11                                                    Chassis Control Module
# 12   DPF #1 Differential Pressure Sensor  / Engine Aftertreatment Control #1
# 13                                                    Chassis Control Module
# 14                                          Engine Aftertreatment Control #1
# 15                                          Engine Aftertreatment Control #1
# 16                                                            Engine Control
# 17                                                              Transmission
# 18                                                        CID: 5522 / MID: -1
# 19                                                            Engine Control
# 20                                                              Transmission
# 21                                                              Transmission
# 22                                                        CID: 5522 / MID: -1
# 23                                                    Chassis Control Module
# 24                                                    Chassis Control Module
# 25                                                    Chassis Control Module
# 26                                                    Chassis Control Module
# 27                                                    Chassis Control Module
# 28                                                    Chassis Control Module
# 29                                                    Chassis Control Module
# 30                                                    Chassis Control Module
# ..                                                                        ...
# 192                      3rd Lever Position Sensor  / Machine Control Module
# 193                      3rd Lever Position Sensor  / Machine Control Module
# 194         Boom Cylinder Head End Pressure Sensor  / Machine Control Module
# 195         Boom Cylinder Head End Pressure Sensor  / Machine Control Module
# 196         Boom Cylinder Head End Pressure Sensor  / Machine Control Module
# 198                                                                    Engine
# 199                                                           Engine Control
# 200                                                           Engine Control
# 201                                    Starter Motor Relay  / Engine Control
# 202                                    Starter Motor Relay  / Engine Control
# 204                             Cellular Antenna  / Communication Gateway #1
# 205                                      CID: 5134 / Steering Control Module
# 206                                                 CID: 5134 / Transmission
# 207                                       CID: 5136 / Machine Control Module
# 208                            Grade Slope Control  / Machine Control Module
# 209                            Local GPS Antenna  / Communication Gateway #1
# 217                                                      Product Link Module
# 218                                                      Product Link Module
# 219                                                      Product Link Module
# 220                                                      Product Link Module
# 221                                                      Product Link Module
# 222                                                      Product Link Module
# 223                                                      Product Link Module
# 224                                                      Product Link Module
# 225       Aftertreatment #1 DEF Pump Motor Speed Sensor  / Engine Control #1
# 226                                                        Engine Control #1
# 227      ARD Fuel Flow Diverter Actuator  / Engine Aftertreatment Control #1
# 228                                         Engine Aftertreatment Control #1
# 229                                           Implement Control Valve Module
# 230                                           Implement Control Valve Module
#
#                                                           Details     SMU  \
# 1                                     Transmission Abuse Warning      NaN
# 2                                     Transmission Abuse Warning      NaN
# 3                                     Low - moderate severity (2)     NaN
# 4                   Low Brake Accumulator Precharge Gas Pressure      NaN
# 5                           Front Cross Axle Lock Speed Mismatch      NaN
# 6                                  Interaxle Lock Speed Mismatch      NaN
# 7        Operator Seat Belt Unfastened While Machine is Not Idle      NaN
# 8                           Unacceptable Machine Rear Roll Angle      NaN
# 9                          High Torque Converter Oil Temperature      NaN
# 10                         High Torque Converter Oil Temperature      NaN
# 11       Operator Seat Belt Unfastened While Machine is Not Idle      NaN
# 12                       Erratic, Intermittent, or Incorrect \r\n     NaN
# 13                                      Low Engine Coolant Level      NaN
# 14            Aftertreatment #1 DEF Dosing Unit #1 Loss of Prime      NaN
# 15        Operator Forced Shutdown with High Exhaust Temperature      NaN
# 16                     Aftertreatment #1 SCR Operator Inducement      NaN
# 17           High Transmission Clutch Accumulated Thermal Energy      NaN
# 18                                   Not Responding Properly \r\n     NaN
# 19                             Low Aftertreatment DEF Tank Level      NaN
# 20                                      Brake Oil Filter Plugged      NaN
# 21                                      Brake Oil Filter Plugged      NaN
# 22                                   Not Responding Properly \r\n     NaN
# 23         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 24         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 25         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 26         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 27         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 28         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 29         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# 30         High Interaxle Lock Clutch Accumulated Thermal Energy      NaN
# ..                                                            ...     ...
# 192                                     Voltage Above Normal \r\n     NaN
# 193                                     Voltage Above Normal \r\n     NaN
# 194                                     Voltage Above Normal \r\n     NaN
# 195                                     Voltage Above Normal \r\n     NaN
# 196                                     Voltage Above Normal \r\n     NaN
# 198                         Delayed Engine Shutdown Override (ET)  1300.0
# 199       Operator Forced Shutdown with High Exhaust Temperature      NaN
# 200                             Delayed Engine Shutdown Override      NaN
# 201                                     Current Below Normal \r\n     NaN
# 202                                     Current Below Normal \r\n     NaN
# 204                                     Voltage Above Normal \r\n     NaN
# 205                                     Abnormal Update Rate \r\n     NaN
# 206                                     Abnormal Update Rate \r\n     NaN
# 207                                     Abnormal Update Rate \r\n     NaN
# 208                                     Abnormal Update Rate \r\n     NaN
# 209                                     Voltage Above Normal \r\n     NaN
# 217                            Operation Time Boundary Violation      NaN
# 218                            Operation Time Boundary Violation      NaN
# 219                            Operation Time Boundary Violation      NaN
# 220                            Operation Time Boundary Violation      NaN
# 221                            Operation Time Boundary Violation      NaN
# 222                            Operation Time Boundary Violation      NaN
# 223                            Operation Time Boundary Violation      NaN
# 224                            Operation Time Boundary Violation      NaN
# 225               Abnormal Frequency, Pulse Width, or Period \r\n     NaN
# 226  Aftertreatment #1 DEF Dosing Unit #1 Input Lines Not Purged      NaN
# 227                                     Current Below Normal \r\n     NaN
# 228                       Low Aftertreatment #1 Fuel Pressure #1      NaN
# 229      Operator Seat Belt Unfastened While Machine is Not Idle      NaN
# 230      Operator Seat Belt Unfastened While Machine is Not Idle      NaN
#
#     Severity                       0           1         2          3  \
# 1        LV1                MID: 389     EID: 47  OCC: 104       None
# 2        LV1                MID: 389     EID: 47  OCC: 103       None
# 3        LV2                 MID: -1   CID: 5519   FMI: 18     OCC: 5
# 4        LV3                MID: 389   EID: 1449    OCC: 1       None
# 5        LV1                MID: 390   EID: 1248    OCC: 1       None
# 6        LV1                MID: 390   EID: 1251    OCC: 1       None
# 7        LV1                MID: 390   EID: 1388    OCC: 6       None
# 8        LV3                MID: 390   EID: 1533    OCC: 2       None
# 9        LV2                MID: 297    EID: 155    OCC: 2       None
# 10       LV2                MID: 297    EID: 155    OCC: 1       None
# 11       LV1                MID: 390   EID: 1388    OCC: 5       None
# 12       LV2                MID: 341   CID: 2458    FMI: 2     OCC: 1
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# ..            ...
# 192          None
# 193          None
# 194          None
# 195          None
# 196          None
# 198   Severity: 3
# 199          None
# 200          None
# 201          None
# 202          None
# 204          None
# 205          None
# 206          None
# 207          None
# 208          None
# 209          None
# 217          None
# 218          None
# 219          None
# 220          None
# 221          None
# 222          None
# 223          None
# 224          None
# 225          None
# 226          None
# 227          None
# 228          None
# 229          None
# 230          None
#
# [183 rows x 13 columns]

# %% [markdown]
# # Second Split

# %%
#MID (column 0)
split2 = eventcat.loc[:, 0].str.split(pat=':', expand=True)
#check unique values
for col in split2:
    print(split2[col].unique())
eventcat[['MIDs', 'MID']] = split2
eventcat = eventcat.drop(columns=[0])
eventcat.head()
# Out:
# ['MID' 'ET/PSR Logged MID']
# [' 389' ' -1' ' 390' ' 297' ' 341' ' 263' ' 272' ' 36' ' 464' ' 432'
#  ' 299' ' 391' ' 264' ' 122' ' 82' ' 39' ' 400']
#          SN            Type      Date                              Message  \
# 1  2T300763       EventCode  04/08/20            MID: 389,EID: 47,OCC: 104
# 2  2T300763       EventCode  04/08/20            MID: 389,EID: 47,OCC: 103
# 3  2T400506  DiagnosticCode  04/09/20  MID: -1, CID: 5519, FMI: 18, OCC: 5
# 4  2T400506       EventCode  04/13/20            MID: 389,EID: 1449,OCC: 1
# 5  2T400517       EventCode  04/08/20            MID: 390,EID: 1248,OCC: 1
#
#                      Description  \
# 1  Transmission/Chassis Control
# 2  Transmission/Chassis Control
# 3            CID: 5519 / MID: -1
# 4  Transmission/Chassis Control
# 5        Chassis Control Module
#
#                                          Details  SMU Severity           1  \
# 1                    Transmission Abuse Warning   NaN      LV1     EID: 47
# 2                    Transmission Abuse Warning   NaN      LV1     EID: 47
# 3                    Low - moderate severity (2)  NaN      LV2   CID: 5519
# 4  Low Brake Accumulator Precharge Gas Pressure   NaN      LV3   EID: 1449
# 5          Front Cross Axle Lock Speed Mismatch   NaN      LV1   EID: 1248
#
#           2        3     4 MIDs   MID
# 1  OCC: 104     None  None  MID   389
# 2  OCC: 103     None  None  MID   389
# 3   FMI: 18   OCC: 5  None  MID    -1
# 4    OCC: 1     None  None  MID   389
# 5    OCC: 1     None  None  MID   390

# %%
#column 1
split2 = eventcat.loc[:, 1].str.split(pat=':', expand=True)
#replace ' CID' to 'CID'
split2[0] = split2[0].replace({' CID': 'CID'})
#check unique values
#for col in split2:
#    print(split2[col].unique())
eventcat[['EIDs', 'EIDValues']] = split2
eventcat = eventcat.drop(columns=[1])
eventcat.head()
pvt = eventcat.pivot(columns='EIDs', values='EIDValues')
eventcat = pd.concat([eventcat, pvt], axis=1).drop(columns=['MIDs', 'EIDs', 'EIDValues'])
#eventcat.info()

# %%
#column 2
split3 = eventcat.loc[:, 2].str.split(pat=':', expand=True)
#replace
split3[0] = split3[0].replace({' FMI': 'FMI', ' Severity': 'Severity_1', 'Severity': 'Severity_1'})
#check unique values
#for col in split3:
#    print(split3[col].unique())
#Concat
eventcat[['occs', 'occValues']] = split3
eventcat = eventcat.drop(columns=[2])
eventcat.head()
pvt = eventcat.pivot(columns='occs', values='occValues')
eventcat = pd.concat([eventcat, pvt], axis=1).drop(columns=['occs', 'occValues'])
#eventcat.head()

# %%
#column 3
split4 = eventcat.loc[:, 3].str.split(pat=':', expand=True)
#replace
split4[0] = split4[0].replace({' OCC': 'OCC_1', 'OCC': 'OCC_1', ' Severity ': 'Severity_2', None: 'None'})
#check unique values
#for col in split4:
#    print(split4[col].unique())
split4 = split4.drop(columns=[2])
#Concat
eventcat[['occs', 'occValues']] = split4
eventcat = eventcat.drop(columns=[3])
eventcat.head()
pvt = eventcat.pivot(columns='occs', values='occValues')
eventcat = pd.concat([eventcat, pvt], axis=1).drop(columns=['occs', 'occValues', 'None'])

# %%
#column 4
split5 = eventcat.loc[:, 4].str.split(pat=':', expand=True)
#replace
split5[0] = split5[0].replace({' Severity': 'Severity_3', None: 'None_1'})
#check unique values
#for col in split5:
#    print(split5[col].unique())
#Concat
eventcat[['occs', 'occValues']] = split5
eventcat = eventcat.drop(columns=[4])
pvt = eventcat.pivot(columns='occs', values='occValues')
eventcat = pd.concat([eventcat, pvt], axis=1).drop(columns=['occs', 'occValues', 'None_1'])
eventcat.head()
# Out:
#          SN            Type      Date                              Message  \
# 1  2T300763       EventCode  04/08/20            MID: 389,EID: 47,OCC: 104
# 2  2T300763       EventCode  04/08/20            MID: 389,EID: 47,OCC: 103
# 3  2T400506  DiagnosticCode  04/09/20  MID: -1, CID: 5519, FMI: 18, OCC: 5
# 4  2T400506       EventCode  04/13/20            MID: 389,EID: 1449,OCC: 1
# 5  2T400517       EventCode  04/08/20            MID: 390,EID: 1248,OCC: 1
#
#                      Description  \
# 1  Transmission/Chassis Control
# 2  Transmission/Chassis Control
# 3            CID: 5519 / MID: -1
# 4  Transmission/Chassis Control
# 5        Chassis Control Module
#
#                                          Details  SMU Severity   MID    CID  \
# 1                    Transmission Abuse Warning   NaN      LV1   389    NaN
# 2                    Transmission Abuse Warning   NaN      LV1   389    NaN
# 3                    Low - moderate severity (2)  NaN      LV2    -1   5519
# 4  Low Brake Accumulator Precharge Gas Pressure   NaN      LV3   389    NaN
# 5          Front Cross Axle Lock Speed Mismatch   NaN      LV1   390    NaN
#
#      EID  FMI   OCC OCC_1 Severity_3
# 1     47  NaN   104   NaN        NaN
# 2     47  NaN   103   NaN        NaN
# 3    NaN   18   NaN     5        NaN
# 4   1449  NaN     1   NaN        NaN
# 5   1248  NaN     1   NaN        NaN

# %%
#write csv
eventcat.to_csv('event_test.csv', index=False)

# %% [markdown]
# # Combine duplicated columns

# %%
type(str(eventcat['OCC_1'].iloc[1])) #.str.cat(eventcat['OCC_1'],sep="")
eventcat['OCC_1']

# %%
def comb(row):
    if row['OCC'].notnull():
        return row['OCC']
    elif row['OCC'].isnull():
        return row['OCC1']

eventcat['occnew'] = eventcat.apply(comb, axis=1)
eventcat.head()
# Out:
#   File "<ipython-input-23-d62437cb0091>", line 4
#     else row['OCC'].isnull():
#            ^
# SyntaxError: invalid syntax
